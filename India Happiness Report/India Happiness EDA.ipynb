# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
colors_mix = ["#17869E", '#264D58', '#179E66', '#D35151', '#E9DAB4', '#E9B4B4', '#D3B651', '#6351D3']

# %%
df = pd.read_csv('world-happiness-report.csv')

# %%
df.head()
# Out:
#   Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 0  Afghanistan  2008        3.724               7.370           0.451
# 1  Afghanistan  2009        4.402               7.540           0.552
# 2  Afghanistan  2010        4.758               7.647           0.539
# 3  Afghanistan  2011        3.832               7.620           0.521
# 4  Afghanistan  2012        3.783               7.705           0.521
#
#    Healthy life expectancy at birth  Freedom to make life choices  Generosity  \
# 0                             50.80                         0.718       0.168
# 1                             51.20                         0.679       0.190
# 2                             51.60                         0.600       0.121
# 3                             51.92                         0.496       0.162
# 4                             52.24                         0.531       0.236
#
#    Perceptions of corruption  Positive affect  Negative affect
# ...

# %%
df1=np.where(df['Country name']=="India")
df2=df.iloc[732:747]
df2
# Out:
#     Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 732        India  2006        5.348               8.145           0.707
# 733        India  2007        5.027               8.204           0.569
# 734        India  2008        5.146               8.220           0.684
# 735        India  2009        4.522               8.281           0.653
# 736        India  2010        4.989               8.349           0.605
# 737        India  2011        4.635               8.387           0.553
# 738        India  2012        4.720               8.428           0.511
# 739        India  2013        4.428               8.478           0.553
# 740        India  2014        4.424               8.538           0.621
# 741        India  2015        4.342               8.604           0.610
# 742        India  2016        4.179               8.673           0.614
# 743        India  2017        4.046               8.730           0.607
# ...

# %%
df=df2

# %%
df2 = pd.read_csv('world-happiness-report.csv')

# %%
df.isnull().sum()
# Out:
# Country name                        0
# year                                0
# Life Ladder                         0
# Log GDP per capita                  0
# Social support                      0
# Healthy life expectancy at birth    0
# Freedom to make life choices        0
# Generosity                          1
# Perceptions of corruption           0
# Positive affect                     0
# Negative affect                     0
# dtype: int64

# %%
mean=df['Life Ladder'].mean()
globalMean=df2['Life Ladder'].mean()
sns.catplot(y='year',x='Life Ladder',kind='bar',data=df,orient='h',palette='Paired')
plt.axvline(mean, color='black', linestyle='--')
plt.axvline(globalMean, color='r', linestyle='dashdot')
avgl  = plt.text(
    s="National Average: {:.2f}".format(mean),
    x=mean*1,
    y=-1,
    fontsize=12,
    fontweight="bold",
    color='black'
)
avgg  = plt.text(
    s="Global Average: {:.2f}".format(globalMean),
    x=globalMean*1.02,
    y=4,
    fontsize=12,
    fontweight="bold",
    color='r'
)
#plt.legend(["National Average", "Global Average"], loc='upper center', bbox_to_anchor=(0.5, -0.2), ncol=5, borderpad=1, frameon=False, fontsize=12)

# %%
mean=df['Log GDP per capita'].mean()
globalMean=df2['Log GDP per capita'].mean()
sns.catplot(y='year',x='Log GDP per capita',kind='bar',data=df,orient='h',palette='Paired')
plt.axvline(mean, color='black', linestyle='--')
plt.axvline(globalMean, color='r', linestyle='dashdot')
avgl  = plt.text(
    s="National Average: {:.2f}".format(mean),
    x=mean*1,
    y=-1,
    fontsize=12,
    fontweight="bold",
    color='black'
)
avgg  = plt.text(
    s="Global Average: {:.2f}".format(globalMean),
    x=globalMean*1.02,
    y=4,
    fontsize=12,
    fontweight="bold",
    color='r'
)

# %%
df.columns
# Out:
# Index(['Country name', 'year', 'Life Ladder', 'Log GDP per capita',
#        'Social support', 'Healthy life expectancy at birth',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption', 'Positive affect', 'Negative affect'],
#       dtype='object')

# %%
mean=df['Social support'].mean()
globalMean=df2['Social support'].mean()
sns.catplot(y='year',x='Social support',kind='bar',data=df,orient='h',palette='Paired')
plt.axvline(mean, color='black', linestyle='--')
plt.axvline(globalMean, color='r', linestyle='dashdot')
avgl  = plt.text(
    s="National Average: {:.2f}".format(mean),
    x=mean*1,
    y=-1,
    fontsize=12,
    fontweight="bold",
    color='black'
)
avgg  = plt.text(
    s="Global Average: {:.2f}".format(globalMean),
    x=globalMean*1.02,
    y=4,
    fontsize=12,
    fontweight="bold",
    color='r'
)

# %%
mean=df['Healthy life expectancy at birth'].mean()
globalMean=df2['Healthy life expectancy at birth'].mean()
sns.catplot(y='year',x='Healthy life expectancy at birth',kind='bar',data=df,orient='h',palette='Paired')
plt.axvline(mean, color='black', linestyle='--')
plt.axvline(globalMean, color='r', linestyle='dashdot')
avgl  = plt.text(
    s="National Average: {:.2f}".format(mean),
    x=mean*1,
    y=-1,
    fontsize=12,
    fontweight="bold",
    color='black'
)
avgg  = plt.text(
    s="Global Average: {:.2f}".format(globalMean),
    x=globalMean*1.02,
    y=4,
    fontsize=12,
    fontweight="bold",
    color='r'
)

# %%
mean=df['Freedom to make life choices'].mean()
globalMean=df2['Freedom to make life choices'].mean()
sns.catplot(y='year',x='Freedom to make life choices',kind='bar',data=df,orient='h',palette='Paired')
plt.axvline(mean, color='black', linestyle='--')
plt.axvline(globalMean, color='r', linestyle='dashdot')
avgl  = plt.text(
    s="National Average: {:.2f}".format(mean),
    x=mean*1.02,
    y=4,
    fontsize=12,
    fontweight="bold",
    color='black'
)
avgg  = plt.text(
    s="Global Average: {:.2f}".format(globalMean),
    x=globalMean*1,
    y=-1,
    fontsize=12,
    fontweight="bold",
    color='r'
)

# %%
mean=df['Generosity'].mean()
globalMean=df2['Generosity'].mean()
sns.catplot(y='year',x='Generosity',kind='bar',data=df,orient='h',palette='Paired')
plt.axvline(mean, color='black', linestyle='--')
plt.axvline(globalMean, color='r', linestyle='dashdot')
avgl  = plt.text(
    s="National Average: {:.2f}".format(mean),
    x=mean*1.02,
    y=3,
    fontsize=12,
    fontweight="bold",
    color='black'
)
avgg  = plt.text(
    s="Global Average: {:.2f}".format(globalMean),
    x=globalMean*1,
    y=-1,
    fontsize=12,
    fontweight="bold",
    color='r'
)

# %%
mean=df['Perceptions of corruption'].mean()
globalMean=df2['Perceptions of corruption'].mean()
sns.catplot(y='year',x='Perceptions of corruption',kind='bar',data=df,orient='h',palette='Paired')
plt.axvline(mean, color='black', linestyle='--')
plt.axvline(globalMean, color='r', linestyle='dashdot')
avgl  = plt.text(
    s="National Average: {:.2f}".format(mean),
    x=mean*1.02,
    y=4,
    fontsize=12,
    fontweight="bold",
    color='black'
)
avgg  = plt.text(
    s="Global Average: {:.2f}".format(globalMean),
    x=globalMean*1,
    y=-1,
    fontsize=12,
    fontweight="bold",
    color='r'
)

# %%
mean=df['Positive affect'].mean()
globalMean=df2['Positive affect'].mean()
sns.catplot(y='year',x='Positive affect',kind='bar',data=df,orient='h',palette='Paired')
plt.axvline(mean, color='black', linestyle='--')
plt.axvline(globalMean, color='r', linestyle='dashdot')
avgl  = plt.text(
    s="National Average: {:.2f}".format(mean),
    x=mean*1,
    y=-1,
    fontsize=12,
    fontweight="bold",
    color='black'
)
avgg  = plt.text(
    s="Global Average: {:.2f}".format(globalMean),
    x=globalMean*1.02,
    y=5,
    fontsize=12,
    fontweight="bold",
    color='r'
)

# %%
mean=df['Negative affect'].mean()
globalMean=df2['Negative affect'].mean()
sns.catplot(y='year',x='Negative affect',kind='bar',data=df,orient='h',palette='Paired')
plt.axvline(mean, color='black', linestyle='--')
plt.axvline(globalMean, color='r', linestyle='dashdot')
avgl  = plt.text(
    s="National Average: {:.2f}".format(mean),
    x=mean*1.02,
    y=4,
    fontsize=12,
    fontweight="bold",
    color='black'
)
avgg  = plt.text(
    s="Global Average: {:.2f}".format(globalMean),
    x=globalMean*1,
    y=-1,
    fontsize=12,
    fontweight="bold",
    color='r'
)

# %%
df.groupby('year').mean()
# Out:
#       Life Ladder  Log GDP per capita  Social support  \
# year
# 2006        5.348               8.145           0.707
# 2007        5.027               8.204           0.569
# 2008        5.146               8.220           0.684
# 2009        4.522               8.281           0.653
# 2010        4.989               8.349           0.605
# 2011        4.635               8.387           0.553
# 2012        4.720               8.428           0.511
# 2013        4.428               8.478           0.553
# 2014        4.424               8.538           0.621
# 2015        4.342               8.604           0.610
# 2016        4.179               8.673           0.614
# 2017        4.046               8.730           0.607
# 2018        3.818               8.779           0.638
# 2019        3.249               8.818           0.561
# 2020        4.225               8.703           0.617
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# year
# ...

# %%
meandf=df2.groupby('year').mean()
meandf.head()
# Out:
#       Life Ladder  Log GDP per capita  Social support  \
# year
# 2005     6.446259           10.118667        0.897407
# 2006     5.196899            9.044284        0.835809
# 2007     5.418275            9.172951        0.807770
# 2008     5.418509            9.167273        0.784391
# 2009     5.457667            9.263805        0.819071
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# year
# 2005                         67.007407                      0.829520
# 2006                         60.147500                      0.730477
# 2007                         61.305267                      0.687337
# 2008                         61.249954                      0.688355
# 2009                         62.418928                      0.687402
#
#       Generosity  Perceptions of corruption  Positive affect  Negative affect
# year
# 2005    0.256000                   0.715880         0.748615         0.255769
# ...

# %%
meandf=meandf.drop([2005],axis=0)

# %%
meandf.head()
# Out:
#       Life Ladder  Log GDP per capita  Social support  \
# year
# 2006     5.196899            9.044284        0.835809
# 2007     5.418275            9.172951        0.807770
# 2008     5.418509            9.167273        0.784391
# 2009     5.457667            9.263805        0.819071
# 2010     5.496806            9.393846        0.831867
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# year
# 2006                         60.147500                      0.730477
# 2007                         61.305267                      0.687337
# 2008                         61.249954                      0.688355
# 2009                         62.418928                      0.687402
# 2010                         63.069025                      0.708262
#
#       Generosity  Perceptions of corruption  Positive affect  Negative affect
# year
# 2006    0.006654                   0.755747         0.719090         0.254614
# ...

# %%
plt.plot(df['year'],meandf['Life Ladder'],label="Global Mean Life Ladder",color="r")
plt.plot(df['year'],df['Life Ladder'],label="National Life Ladder",color="black")
plt.legend()
plt.xlabel("Year")
plt.ylabel("Life Ladder")
plt.show()

# %%
plt.plot(df['year'],meandf['Log GDP per capita'],label="Global Mean Log GDP per capita",color="r")
plt.plot(df['year'],df['Log GDP per capita'],label="National Log GDP per capita",color="black")
plt.legend()
plt.xlabel("Year")
plt.ylabel("Log GDP per capita")
plt.show()

# %%
plt.plot(df['year'],meandf['Social support'],label="Global Mean Social support",color="r")
plt.plot(df['year'],df['Social support'],label="National Social support",color="black")
plt.legend()
plt.xlabel("Year")
plt.ylabel("Social support")
plt.show()

# %%
plt.plot(df['year'],meandf['Healthy life expectancy at birth'],label="Global Mean Healthy life expectancy at birth",color="r")
plt.plot(df['year'],df['Healthy life expectancy at birth'],label="National Healthy life expectancy at birth",color="black")
plt.legend()
plt.xlabel("Year")
plt.ylabel("Healthy life expectancy at birth")
plt.show()

# %%
plt.plot(df['year'],meandf['Freedom to make life choices'],label="Global Mean Freedom to make life choices",color="r")
plt.plot(df['year'],df['Freedom to make life choices'],label="National Freedom to make life choices",color="black")
plt.legend()
plt.xlabel("Year")
plt.ylabel("Freedom to make life choices")
plt.show()

# %%
plt.plot(df['year'],meandf['Generosity'],label="Global Mean Generosity",color="r")
plt.plot(df['year'],df['Generosity'],label="National Generosity",color="black")
plt.legend()
plt.xlabel("Year")
plt.ylabel("Generosity")
plt.show()

# %%
plt.plot(df['year'],meandf['Perceptions of corruption'],label="Global Mean Perceptions of corruption",color="r")
plt.plot(df['year'],df['Perceptions of corruption'],label="National Perceptions of corruption",color="black")
plt.legend()
plt.xlabel("Year")
plt.ylabel("Perceptions of corruption")
plt.show()

# %%
plt.plot(df['year'],meandf['Positive affect'],label="Global Mean Positive affect",color="r")
plt.plot(df['year'],df['Positive affect'],label="National Positive affect",color="black")
plt.legend()
plt.xlabel("Year")
plt.ylabel("Positive affect")
plt.show()

# %%
plt.plot(df['year'],meandf['Negative affect'],label="Global Mean Negative affect",color="r")
plt.plot(df['year'],df['Negative affect'],label="National Negative affect",color="black")
plt.legend()
plt.xlabel("Year")
plt.ylabel("Negative affect")
plt.show()

# %%
df_glob = pd.read_csv('world-happiness-report-2021.csv')

# %%
df_glob.head()
# Out:
#   Country name Regional indicator  Ladder score  \
# 0      Finland     Western Europe         7.842
# 1      Denmark     Western Europe         7.620
# 2  Switzerland     Western Europe         7.571
# 3      Iceland     Western Europe         7.554
# 4  Netherlands     Western Europe         7.464
#
#    Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                           0.032         7.904         7.780
# 1                           0.035         7.687         7.552
# 2                           0.036         7.643         7.500
# 3                           0.059         7.670         7.438
# 4                           0.027         7.518         7.410
#
#    Logged GDP per capita  Social support  Healthy life expectancy  \
# 0                 10.775           0.954                     72.0
# 1                 10.933           0.954                     72.7
# 2                 11.117           0.942                     74.4
# ...

# %%
df_reg = df_glob.sort_values("Regional indicator", ascending=False).reset_index(drop=True)
df1=np.where(df_reg['Regional indicator']=="South Asia")
df1
df_reg=df_reg.iloc[66:73]

# %%
df_reg
# Out:
#    Country name Regional indicator  Ladder score  \
# 66     Maldives         South Asia         5.198
# 67        Nepal         South Asia         5.269
# 68    Sri Lanka         South Asia         4.325
# 69        India         South Asia         3.819
# 70     Pakistan         South Asia         4.934
# 71   Bangladesh         South Asia         5.025
# 72  Afghanistan         South Asia         2.523
#
#     Standard error of ladder score  upperwhisker  lowerwhisker  \
# 66                           0.072         5.339         5.057
# 67                           0.070         5.406         5.132
# 68                           0.066         4.454         4.196
# 69                           0.026         3.869         3.769
# 70                           0.068         5.066         4.802
# 71                           0.046         5.115         4.934
# 72                           0.038         2.596         2.449
#
# ...

# %%
df_sort=df_glob.sort_values("Ladder score", ascending=False).reset_index(drop=True)
df_sort.tail()
# Out:
#     Country name  Regional indicator  Ladder score  \
# 144      Lesotho  Sub-Saharan Africa         3.512
# 145     Botswana  Sub-Saharan Africa         3.467
# 146       Rwanda  Sub-Saharan Africa         3.415
# 147     Zimbabwe  Sub-Saharan Africa         3.145
# 148  Afghanistan          South Asia         2.523
#
#      Standard error of ladder score  upperwhisker  lowerwhisker  \
# 144                           0.120         3.748         3.276
# 145                           0.074         3.611         3.322
# 146                           0.068         3.548         3.282
# 147                           0.058         3.259         3.030
# 148                           0.038         2.596         2.449
#
#      Logged GDP per capita  Social support  Healthy life expectancy  \
# 144                  7.926           0.787                   48.700
# 145                  9.782           0.784                   59.269
# ...

# %%
df_sort=df_glob.sort_values("Ladder score", ascending=False).reset_index(drop=True)
df_glob_comp=df_sort.loc[(df_sort.index==0)|(df_sort.index==1)|(df_sort['Country name']=="India")|(df_sort.index==147)|(df_sort.index==148)]
sns.catplot(x='Country name',y='Ladder score',kind='bar',data=df_glob_comp,palette='Paired')
mean=df_glob_comp['Ladder score'].mean()
plt.axhline(mean, color='black', linestyle='--')
avgl  = plt.text(
    s="Average: {:.2f}".format(mean),
    x=4.6,
    y=mean,
    fontsize=12,
    fontweight="bold",
    color='black'
)
rank=df_sort[df_sort["Country name"]=="India"].index
list(rank-1)
plt.text(
    s=str(rank[0])+"th",
    x=1.66,
    y=3.1,
    fontsize=16,
    fontweight="bold",
    color='black'
)
plt.text(
    s="1st",
    x=-0.24,
    y=7,
    fontsize=16,
    fontweight="bold",
    color='white'
)

plt.text(
    s="2nd",
    x=0.75,
    y=7,
    fontsize=16,
    fontweight="bold",
    color='white'
)
plt.text(
    s="146th",
    x=2.65,
    y=2.5,
    fontsize=16,
    fontweight="bold",
    color='white'
)
plt.text(
    s="147th",
    x=3.65,
    y=2,
    fontsize=16,
    fontweight="bold",
    color='white'
)
# Out:
# Text(3.65, 2, '147th')

# %%
df_reg_sort=df_reg.sort_values("Ladder score", ascending=False).reset_index(drop=True)
sns.catplot(x='Country name',y='Ladder score',kind='bar',data=df_reg_sort,palette='Paired',aspect=11.7/8.27,)
mean=df_reg_sort['Ladder score'].mean()
plt.axhline(mean, color='black', linestyle='--')
avgl  = plt.text(
    s="Average: {:.2f}".format(mean),
    x=6.6,
    y=mean,
    fontsize=12,
    fontweight="bold",
    color='black'
)
df_sort=df_glob.sort_values("Ladder score", ascending=False).reset_index(drop=True)
rank=[]
for i in range(0,7):
    rank.append(list(df_sort[df_sort["Country name"]==df_reg_sort.loc[i]["Country name"]].index))
plt.text(
    s=str(rank[0][0])+"th",
    x=-0.3,
    y=4.7,
    fontsize=16,
    fontweight="bold",
    color='black'
)
plt.text(
    s=str(rank[1][0])+"th",
    x=0.75,
    y=4.7,
    fontsize=16,
    fontweight="bold",
    color='white'
) 
plt.text(
    s=str(rank[2][0])+"th",
    x=1.7,
    y=4.6,
    fontsize=16,
    fontweight="bold",
    color='white'
) 
plt.text(
    s=str(rank[3][0])+"th",
    x=2.7,
    y=4.5,
    fontsize=16,
    fontweight="bold",
    color='white'
) 
plt.text(
    s=str(rank[4][0])+"th",
    x=3.7,
    y=3.9,
    fontsize=16,
    fontweight="bold",
    color='white'
)
plt.text(
    s=str(rank[5][0])+"th",
    x=4.67,
    y=3.4,
    fontsize=16,
    fontweight="bold",
    color='black'
) 
plt.text(
    s=str(rank[6][0])+"th",
    x=5.65,
    y=2.1,
    fontsize=16,
    fontweight="bold",
    color='white'
)
# Out:
# Text(5.65, 2.1, '148th')

# %%
df_sort=df_glob.sort_values("Logged GDP per capita", ascending=False).reset_index(drop=True)
df_glob_comp=df_sort.loc[(df_sort.index==0)|(df_sort.index==1)|(df_sort['Country name']=="India")|(df_sort.index==147)|(df_sort.index==148)]
sns.catplot(x='Country name',y='Logged GDP per capita',kind='bar',data=df_glob_comp,palette='Paired')
mean=df_glob_comp['Logged GDP per capita'].mean()
plt.axhline(mean, color='black', linestyle='--')
avgl  = plt.text(
    s="Average: {:.2f}".format(mean),
    x=4.6,
    y=mean,
    fontsize=12,
    fontweight="bold",
    color='black'
)
rank=df_sort[df_sort["Country name"]=="India"].index
list(rank-1)
plt.text(
    s=str(rank[0])+"th",
    x=1.66,
    y=7.5,
    fontsize=16,
    fontweight="bold",
    color='black'
)
plt.text(
    s="1st",
    x=-0.24,
    y=10,
    fontsize=16,
    fontweight="bold",
    color='white'
)

plt.text(
    s="2nd",
    x=0.75,
    y=10,
    fontsize=16,
    fontweight="bold",
    color='white'
)
plt.text(
    s="146th",
    x=2.65,
    y=5.6,
    fontsize=16,
    fontweight="bold",
    color='white'
)
plt.text(
    s="147th",
    x=3.65,
    y=5.5,
    fontsize=16,
    fontweight="bold",
    color='white'
)
# Out:
# Text(3.65, 5.5, '147th')

# %%
df_reg_sort=df_reg.sort_values("Logged GDP per capita", ascending=False).reset_index(drop=True)
sns.catplot(x='Country name',y='Logged GDP per capita',kind='bar',data=df_reg_sort,palette='Paired',aspect=11.7/8.27,)
mean=df_reg_sort['Logged GDP per capita'].mean()
plt.axhline(mean, color='black', linestyle='--')
avgl  = plt.text(
    s="Average: {:.2f}".format(mean),
    x=6.6,
    y=mean,
    fontsize=12,
    fontweight="bold",
    color='black'
)
df_sort=df_glob.sort_values("Logged GDP per capita", ascending=False).reset_index(drop=True)
rank=[]
for i in range(0,7):
    rank.append(list(df_sort[df_sort["Country name"]==df_reg_sort.loc[i]["Country name"]].index))
plt.text(
    s=str(rank[0][0])+"th",
    x=-0.26,
    y=9,
    fontsize=16,
    fontweight="bold",
    color='white'
)
plt.text(
    s=str(rank[1][0])+"th",
    x=0.75,
    y=8,
    fontsize=16,
    fontweight="bold",
    color='white'
) 
plt.text(
    s=str(rank[2][0])+"th",
    x=1.68,
    y=7.5,
    fontsize=16,
    fontweight="bold",
    color='black'
) 
plt.text(
    s=str(rank[3][0])+"th",
    x=2.68,
    y=7.5,
    fontsize=16,
    fontweight="bold",
    color='white'
) 
plt.text(
    s=str(rank[4][0])+"th",
    x=3.68,
    y=7.5,
    fontsize=16,
    fontweight="bold",
    color='white'
)
plt.text(
    s=str(rank[5][0])+"th",
    x=4.68,
    y=7.1,
    fontsize=16,
    fontweight="bold",
    color='white'
) 
plt.text(
    s=str(rank[6][0])+"th",
    x=5.68,
    y=6.7,
    fontsize=16,
    fontweight="bold",
    color='white'
)
# Out:
# Text(5.68, 6.7, '132th')

# %%
df_sort=df_glob.sort_values("Social support", ascending=False).reset_index(drop=True)
df_glob_comp=df_sort.loc[(df_sort.index==0)|(df_sort.index==1)|(df_sort['Country name']=="India")|(df_sort.index==147)|(df_sort.index==148)]
sns.catplot(x='Country name',y='Social support',kind='bar',data=df_glob_comp,palette='Paired')
mean=df_glob_comp['Social support'].mean()
plt.axhline(mean, color='black', linestyle='--')
avgl  = plt.text(
    s="Average: {:.2f}".format(mean),
    x=4.6,
    y=mean,
    fontsize=12,
    fontweight="bold",
    color='black'
)
rank=df_sort[df_sort["Country name"]=="India"].index
list(rank-1)
plt.text(
    s=str(rank[0])+"th",
    x=1.66,
    y=0.48,
    fontsize=16,
    fontweight="bold",
    color='black'
)
plt.text(
    s="1st",
    x=-0.24,
    y=0.8,
    fontsize=16,
    fontweight="bold",
    color='white'
)

plt.text(
    s="2nd",
    x=0.75,
    y=0.8,
    fontsize=16,
    fontweight="bold",
    color='white'
)
plt.text(
    s="146th",
    x=2.65,
    y=0.4,
    fontsize=16,
    fontweight="bold",
    color='white'
)
plt.text(
    s="147th",
    x=3.65,
    y=0.37,
    fontsize=16,
    fontweight="bold",
    color='white'
)
# Out:
# Text(3.65, 0.37, '147th')

# %%
df_reg_sort=df_reg.sort_values("Social support", ascending=False).reset_index(drop=True)
sns.catplot(x='Country name',y='Social support',kind='bar',data=df_reg_sort,palette='Paired',aspect=11.7/8.27,)
mean=df_reg_sort['Social support'].mean()
plt.axhline(mean, color='black', linestyle='--')
avgl  = plt.text(
    s="Average: {:.2f}".format(mean),
    x=6.6,
    y=mean,
    fontsize=12,
    fontweight="bold",
    color='black'
)
df_sort=df_glob.sort_values("Social support", ascending=False).reset_index(drop=True)
rank=[]
for i in range(0,7):
    rank.append(list(df_sort[df_sort["Country name"]==df_reg_sort.loc[i]["Country name"]].index))
plt.text(
    s=str(rank[0][0])+"th",
    x=-0.3,
    y=0.8,
    fontsize=16,
    fontweight="bold",
    color='white'
)
plt.text(
    s=str(rank[1][0])+"th",
    x=0.75,
    y=0.75,
    fontsize=16,
    fontweight="bold",
    color='white'
) 
plt.text(
    s=str(rank[2][0])+"th",
    x=1.68,
    y=0.62,
    fontsize=16,
    fontweight="bold",
    color='white'
) 
plt.text(
    s=str(rank[3][0])+"th",
    x=2.68,
    y=0.62,
    fontsize=16,
    fontweight="bold",
    color='white'
) 
plt.text(
    s=str(rank[4][0])+"th",
    x=3.68,
    y=0.58,
    fontsize=16,
    fontweight="bold",
    color='white'
)
plt.text(
    s=str(rank[5][0])+"th",
    x=4.68,
    y=0.54,
    fontsize=16,
    fontweight="bold",
    color='black'
) 
plt.text(
    s=str(rank[6][0])+"th",
    x=5.68,
    y=0.4,
    fontsize=16,
    fontweight="bold",
    color='white'
)
# Out:
# Text(5.68, 0.4, '148th')

# %%
df_sort=df_glob.sort_values("Healthy life expectancy", ascending=False).reset_index(drop=True)
df_glob_comp=df_sort.loc[(df_sort.index==0)|(df_sort.index==1)|(df_sort['Country name']=="India")|(df_sort.index==147)|(df_sort.index==148)]
sns.catplot(x='Country name',y='Healthy life expectancy',kind='bar',data=df_glob_comp,palette='Paired',aspect=100/50)
mean=df_glob_comp['Healthy life expectancy'].mean()
plt.axhline(mean, color='black', linestyle='--')
avgl  = plt.text(
    s="Average: {:.2f}".format(mean),
    x=4.6,
    y=mean,
    fontsize=12,
    fontweight="bold",
    color='black'
)
rank=df_sort[df_sort["Country name"]=="India"].index
list(rank-1)
plt.text(
    s=str(rank[0])+"th",
    x=1.79,
    y=53,
    fontsize=18,
    fontweight="bold",
    color='black'
)
plt.text(
    s="1st",
    x=-0.1,
    y=70,
    fontsize=18,
    fontweight="bold",
    color='white'
)

plt.text(
    s="2nd",
    x=0.85,
    y=70,
    fontsize=18,
    fontweight="bold",
    color='white'
)
plt.text(
    s="146th",
    x=2.8,
    y=42,
    fontsize=18,
    fontweight="bold",
    color='white'
)
plt.text(
    s="147th",
    x=3.8,
    y=42,
    fontsize=18,
    fontweight="bold",
    color='white'
)
# Out:
# Text(3.8, 42, '147th')

# %%
df_reg_sort=df_reg.sort_values("Healthy life expectancy", ascending=False).reset_index(drop=True)
sns.catplot(x='Country name',y='Healthy life expectancy',kind='bar',data=df_reg_sort,palette='Paired',aspect=11.7/8.27,)
mean=df_reg_sort['Healthy life expectancy'].mean()
plt.axhline(mean, color='black', linestyle='--')
avgl  = plt.text(
    s="Average: {:.2f}".format(mean),
    x=6.6,
    y=mean,
    fontsize=12,
    fontweight="bold",
    color='black'
)
df_sort=df_glob.sort_values("Healthy life expectancy", ascending=False).reset_index(drop=True)
rank=[]
for i in range(0,7):
    rank.append(list(df_sort[df_sort["Country name"]==df_reg_sort.loc[i]["Country name"]].index))
plt.text(
    s=str(rank[0][0])+"th",
    x=-0.3,
    y=65,
    fontsize=16,
    fontweight="bold",
    color='white'
)
plt.text(
    s=str(rank[1][0])+"th",
    x=0.75,
    y=56,
    fontsize=16,
    fontweight="bold",
    color='white'
) 
plt.text(
    s=str(rank[2][0])+"th",
    x=1.75,
    y=56,
    fontsize=16,
    fontweight="bold",
    color='white'
) 
plt.text(
    s=str(rank[3][0])+"th",
    x=2.75,
    y=56,
    fontsize=16,
    fontweight="bold",
    color='white'
) 
plt.text(
    s=str(rank[4][0])+"th",
    x=3.68,
    y=52,
    fontsize=16,
    fontweight="bold",
    color='black'
)
plt.text(
    s=str(rank[5][0])+"th",
    x=4.7,
    y=52,
    fontsize=16,
    fontweight="bold",
    color='white'
) 
plt.text(
    s=str(rank[6][0])+"th",
    x=5.68,
    y=45,
    fontsize=16,
    fontweight="bold",
    color='white'
)
# Out:
# Text(5.68, 45, '141th')

# %%
df_sort=df_glob.sort_values("Freedom to make life choices", ascending=False).reset_index(drop=True)
df_glob_comp=df_sort.loc[(df_sort.index==0)|(df_sort.index==1)|(df_sort['Country name']=="India")|(df_sort.index==147)|(df_sort.index==148)]
sns.catplot(x='Country name',y='Freedom to make life choices',kind='bar',data=df_glob_comp,palette='Paired')
mean=df_glob_comp['Freedom to make life choices'].mean()
plt.axhline(mean, color='black', linestyle='--')
avgl  = plt.text(
    s="Average: {:.2f}".format(mean),
    x=4.6,
    y=mean,
    fontsize=12,
    fontweight="bold",
    color='black'
)
rank=df_sort[df_sort["Country name"]=="India"].index
list(rank-1)
plt.text(
    s=str(rank[0])+"th",
    x=1.7,
    y=0.8,
    fontsize=16,
    fontweight="bold",
    color='black'
)
plt.text(
    s="1st",
    x=-0.24,
    y=0.8,
    fontsize=16,
    fontweight="bold",
    color='white'
)

plt.text(
    s="2nd",
    x=0.75,
    y=0.8,
    fontsize=16,
    fontweight="bold",
    color='white'
)
plt.text(
    s="146th",
    x=2.65,
    y=0.4,
    fontsize=16,
    fontweight="bold",
    color='white'
)
plt.text(
    s="147th",
    x=3.65,
    y=0.3,
    fontsize=16,
    fontweight="bold",
    color='white'
)
# Out:
# Text(3.65, 0.3, '147th')

# %%
df_reg_sort=df_reg.sort_values("Freedom to make life choices", ascending=False).reset_index(drop=True)
sns.catplot(x='Country name',y='Freedom to make life choices',kind='bar',data=df_reg_sort,palette='Paired',aspect=11.7/8.27,)
mean=df_reg_sort['Freedom to make life choices'].mean()
plt.axhline(mean, color='black', linestyle='--')
avgl  = plt.text(
    s="Average: {:.2f}".format(mean),
    x=6.6,
    y=mean,
    fontsize=12,
    fontweight="bold",
    color='black'
)
df_sort=df_glob.sort_values("Freedom to make life choices", ascending=False).reset_index(drop=True)
rank=[]
for i in range(0,7):
    rank.append(list(df_sort[df_sort["Country name"]==df_reg_sort.loc[i]["Country name"]].index))
plt.text(
    s=str(rank[0][0])+"th",
    x=-0.3,
    y=0.8,
    fontsize=16,
    fontweight="bold",
    color='black'
)
plt.text(
    s=str(rank[1][0])+"th",
    x=0.75,
    y=0.7,
    fontsize=16,
    fontweight="bold",
    color='white'
) 
plt.text(
    s=str(rank[2][0])+"th",
    x=1.75,
    y=0.7,
    fontsize=16,
    fontweight="bold",
    color='white'
) 
plt.text(
    s=str(rank[3][0])+"th",
    x=2.75,
    y=0.7,
    fontsize=16,
    fontweight="bold",
    color='white'
) 
plt.text(
    s=str(rank[4][0])+"th",
    x=3.75,
    y=0.7,
    fontsize=16,
    fontweight="bold",
    color='white'
)
plt.text(
    s=str(rank[5][0])+"th",
    x=4.7,
    y=0.65,
    fontsize=16,
    fontweight="bold",
    color='white'
) 
plt.text(
    s=str(rank[6][0])+"th",
    x=5.68,
    y=0.3,
    fontsize=16,
    fontweight="bold",
    color='white'
)
# Out:
# Text(5.68, 0.3, '148th')

# %%
df_sort=df_glob.sort_values("Generosity", ascending=False).reset_index(drop=True)
df_glob_comp=df_sort.loc[(df_sort.index==0)|(df_sort.index==1)|(df_sort['Country name']=="India")|(df_sort.index==147)|(df_sort.index==148)]
sns.catplot(x='Country name',y='Generosity',kind='bar',data=df_glob_comp,palette='Paired')
mean=df_glob_comp['Generosity'].mean()
plt.axhline(mean, color='black', linestyle='--')
avgl  = plt.text(
    s="Average: {:.2f}".format(mean),
    x=4.6,
    y=mean,
    fontsize=12,
    fontweight="bold",
    color='black'
)
rank=df_sort[df_sort["Country name"]=="India"].index
list(rank-1)
plt.text(
    s=str(rank[0])+"th",
    x=1.7,
    y=0.04,
    fontsize=16,
    fontweight="bold",
    color='black'
)
plt.text(
    s="1st",
    x=-0.24,
    y=0.4,
    fontsize=16,
    fontweight="bold",
    color='white'
)

plt.text(
    s="2nd",
    x=0.75,
    y=0.4,
    fontsize=16,
    fontweight="bold",
    color='white'
)
plt.text(
    s="146th",
    x=2.65,
    y=-0.1,
    fontsize=16,
    fontweight="bold",
    color='white'
)
plt.text(
    s="147th",
    x=3.65,
    y=-0.1,
    fontsize=16,
    fontweight="bold",
    color='white'
)
# Out:
# Text(3.65, -0.1, '147th')

# %%
df_reg_sort=df_reg.sort_values("Generosity", ascending=False).reset_index(drop=True)
sns.catplot(x='Country name',y='Generosity',kind='bar',data=df_reg_sort,palette='Paired',aspect=11.7/8.27,)
mean=df_reg_sort['Generosity'].mean()
plt.axhline(mean, color='black', linestyle='--')
avgl  = plt.text(
    s="Average: {:.2f}".format(mean),
    x=6.6,
    y=mean,
    fontsize=12,
    fontweight="bold",
    color='black'
)
df_sort=df_glob.sort_values("Generosity", ascending=False).reset_index(drop=True)
rank=[]
for i in range(0,7):
    rank.append(list(df_sort[df_sort["Country name"]==df_reg_sort.loc[i]["Country name"]].index))
plt.text(
    s=str(rank[0][0])+"th",
    x=-0.25,
    y=0.13,
    fontsize=16,
    fontweight="bold",
    color='white'
)
plt.text(
    s=str(rank[1][0])+"th",
    x=0.75,
    y=0.08,
    fontsize=16,
    fontweight="bold",
    color='white'
) 
plt.text(
    s=str(rank[2][0])+"th",
    x=1.75,
    y=0.07,
    fontsize=16,
    fontweight="bold",
    color='black'
) 
plt.text(
    s=str(rank[3][0])+"th",
    x=2.75,
    y=0.06,
    fontsize=16,
    fontweight="bold",
    color='white'
) 
plt.text(
    s=str(rank[4][0])+"th",
    x=3.75,
    y=0.005,
    fontsize=16,
    fontweight="bold",
    color='white'
)
plt.text(
    s=str(rank[5][0])+"th",
    x=4.75,
    y=-0.03,
    fontsize=16,
    fontweight="bold",
    color='white'
) 
plt.text(
    s=str(rank[6][0])+"th",
    x=5.68,
    y=-0.09,
    fontsize=16,
    fontweight="bold",
    color='white'
)
# Out:
# Text(5.68, -0.09, '102th')

# %%
df_sort=df_glob.sort_values("Perceptions of corruption", ascending=False).reset_index(drop=True)
df_glob_comp=df_sort.loc[(df_sort.index==0)|(df_sort.index==1)|(df_sort['Country name']=="India")|(df_sort.index==147)|(df_sort.index==148)]
sns.catplot(x='Country name',y='Perceptions of corruption',kind='bar',data=df_glob_comp,palette='Paired')
mean=df_glob_comp['Perceptions of corruption'].mean()
plt.axhline(mean, color='black', linestyle='--')
avgl  = plt.text(
    s="Average: {:.2f}".format(mean),
    x=4.6,
    y=mean,
    fontsize=12,
    fontweight="bold",
    color='black'
)
rank=df_sort[df_sort["Country name"]=="India"].index
list(rank-1)
plt.text(
    s=str(rank[0])+"th",
    x=1.7,
    y=0.65,
    fontsize=16,
    fontweight="bold",
    color='black'
)
plt.text(
    s="1st",
    x=-0.24,
    y=0.8,
    fontsize=16,
    fontweight="bold",
    color='white'
)

plt.text(
    s="2nd",
    x=0.75,
    y=0.8,
    fontsize=16,
    fontweight="bold",
    color='white'
)
plt.text(
    s="146th",
    x=2.65,
    y=0.1,
    fontsize=16,
    fontweight="bold",
    color='white'
)
plt.text(
    s="147th",
    x=3.65,
    y=0.01,
    fontsize=16,
    fontweight="bold",
    color='white'
)
# Out:
# Text(3.65, 0.01, '147th')

# %%
df_reg_sort=df_reg.sort_values("Perceptions of corruption", ascending=False).reset_index(drop=True)
sns.catplot(x='Country name',y='Perceptions of corruption',kind='bar',data=df_reg_sort,palette='Paired',aspect=11.7/8.27,)
mean=df_reg_sort['Perceptions of corruption'].mean()
plt.axhline(mean, color='black', linestyle='--')
avgl  = plt.text(
    s="Average: {:.2f}".format(mean),
    x=6.6,
    y=mean,
    fontsize=12,
    fontweight="bold",
    color='black'
)
df_sort=df_glob.sort_values("Perceptions of corruption", ascending=False).reset_index(drop=True)
rank=[]
for i in range(0,7):
    rank.append(list(df_sort[df_sort["Country name"]==df_reg_sort.loc[i]["Country name"]].index))
plt.text(
    s=str(rank[0][0])+"th",
    x=-0.2,
    y=0.85,
    fontsize=16,
    fontweight="bold",
    color='white'
)
plt.text(
    s=str(rank[1][0])+"th",
    x=0.75,
    y=0.74,
    fontsize=16,
    fontweight="bold",
    color='white'
) 
plt.text(
    s=str(rank[2][0])+"th",
    x=1.75,
    y=0.7,
    fontsize=16,
    fontweight="bold",
    color='white'
) 
plt.text(
    s=str(rank[3][0])+"th",
    x=2.75,
    y=0.7,
    fontsize=16,
    fontweight="bold",
    color='white'
) 
plt.text(
    s=str(rank[4][0])+"th",
    x=3.75,
    y=0.7,
    fontsize=16,
    fontweight="bold",
    color='black'
)
plt.text(
    s=str(rank[5][0])+"th",
    x=4.75,
    y=0.65,
    fontsize=16,
    fontweight="bold",
    color='white'
) 
plt.text(
    s=str(rank[6][0])+"th",
    x=5.68,
    y=0.6,
    fontsize=16,
    fontweight="bold",
    color='white'
)
# Out:
# Text(5.68, 0.6, '109th')

# %%
region=df_glob.groupby('Regional indicator').mean()
region
region_name=['Central and Eastern Europe','Commonwealth of Independent States','East Asia','Latin America and Caribbean','Middle East and North Africa','North America and ANZ','South Asia','Southeast Asia','Sub-Saharan Africa','Western Europe']
region['Regional indicator']=region_name

# %%
region.columns
# Out:
# Index(['Ladder score', 'Standard error of ladder score', 'upperwhisker',
#        'lowerwhisker', 'Logged GDP per capita', 'Social support',
#        'Healthy life expectancy', 'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption', 'Ladder score in Dystopia',
#        'Explained by: Log GDP per capita', 'Explained by: Social support',
#        'Explained by: Healthy life expectancy',
#        'Explained by: Freedom to make life choices',
#        'Explained by: Generosity', 'Explained by: Perceptions of corruption',
#        'Dystopia + residual', 'Regional indicator'],
#       dtype='object')

# %%
region_sort=region.sort_values("Ladder score", ascending=False).reset_index(drop=True)
sns.catplot(x='Regional indicator',y='Ladder score',kind='bar',data=region_sort,palette='Paired',aspect=9/2)
rmean=region['Ladder score'].mean()
plt.axhline(rmean, color='black', linestyle='--')
avgl  = plt.text(
    s="Average: {:.2f}".format(rmean),
    x=8.7,
    y=mean*1.02,
    fontsize=14,
    fontweight="bold",
    color='black'
)

# %%
region_sort=region.sort_values("Logged GDP per capita", ascending=False).reset_index(drop=True)
sns.catplot(x='Regional indicator',y='Logged GDP per capita',kind='bar',data=region_sort,palette='Paired',aspect=9.8/2)
rmean=region['Logged GDP per capita'].mean()
plt.axhline(rmean, color='black', linestyle='--')
avgl  = plt.text(
    s="Average: {:.2f}".format(rmean),
    x=9.5,
    y=rmean*1.02,
    fontsize=14,
    fontweight="bold",
    color='black'
)

# %%
region_sort=region.sort_values("Social support", ascending=False).reset_index(drop=True)
sns.catplot(x='Regional indicator',y='Social support',kind='bar',data=region_sort,palette='Paired',aspect=9/2)
rmean=region['Social support'].mean()
plt.axhline(rmean, color='black', linestyle='--')
avgl  = plt.text(
    s="Average: {:.2f}".format(rmean),
    x=8.7,
    y=rmean*1.02,
    fontsize=14,
    fontweight="bold",
    color='black'
)

# %%
region_sort=region.sort_values("Healthy life expectancy", ascending=False).reset_index(drop=True)
sns.catplot(x='Regional indicator',y='Healthy life expectancy',kind='bar',data=region_sort,palette='Paired',aspect=9.8/2)
rmean=region['Healthy life expectancy'].mean()
plt.axhline(rmean, color='black', linestyle='--')
avgl  = plt.text(
    s="Average: {:.2f}".format(rmean),
    x=8.7,
    y=rmean*1.02,
    fontsize=14,
    fontweight="bold",
    color='black'
)

# %%
region_sort=region.sort_values("Freedom to make life choices", ascending=False).reset_index(drop=True)
sns.catplot(x='Regional indicator',y='Freedom to make life choices',kind='bar',data=region_sort,palette='Paired',aspect=9.8/2)
rmean=region['Freedom to make life choices'].mean()
plt.axhline(rmean, color='black', linestyle='--')
avgl  = plt.text(
    s="Average: {:.2f}".format(rmean),
    x=8.7,
    y=rmean*1.02,
    fontsize=14,
    fontweight="bold",
    color='black'
)

# %%
region_sort=region.sort_values("Generosity", ascending=False).reset_index(drop=True)
sns.catplot(x='Regional indicator',y='Generosity',kind='bar',data=region_sort,palette='Paired',aspect=9/2)
rmean=region['Generosity'].mean()
plt.axhline(rmean, color='black', linestyle='--')
avgl  = plt.text(
    s="Average: {:.2f}".format(rmean),
    x=9.5,
    y=rmean*1.02,
    fontsize=14,
    fontweight="bold",
    color='black'
)

# %%
region_sort=region.sort_values("Perceptions of corruption", ascending=False).reset_index(drop=True)
sns.catplot(x='Regional indicator',y='Perceptions of corruption',kind='bar',data=region_sort,palette='Paired',aspect=9/2)
rmean=region['Perceptions of corruption'].mean()
plt.axhline(rmean, color='black', linestyle='--')
avgl  = plt.text(
    s="Average: {:.2f}".format(rmean),
    x=9.5,
    y=rmean*1.02,
    fontsize=14,
    fontweight="bold",
    color='black'
)
